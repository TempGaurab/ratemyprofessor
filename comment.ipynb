# %%
import pandas as pd
import numpy
from bs4 import BeautifulSoup
import selenium
import requests as req

# %%
df = pd.read_csv("423professors_updated.csv")
df
# Out:
#                   Name  Rating Value  Rating Count            Course  \
# 0     Michael Simonton           5.0           154      Anthropology
# 1     Charlie Roetting           4.9            18           Theater
# 2         James Skaggs           4.9           100     Communication
# 3     Marissa McKinley           5.0             6           English
# 4         Kenneth Lowe           5.0             3       Engineering
# ..                 ...           ...           ...               ...
# 418          Alex Khul           0.0             0  Computer Science
# 419  Hanieh  Shabanian           0.0             0  Computer Science
# 420    Sylvester Addae           0.0             0  Computer Science
# 421        Jason White           0.0             0  Computer Science
# 422    Kazi Zunnurhain           2.0             1  Computer Science
#
#      Would Take Again  Difficulty                    University  \
# 0                0.96         1.5  Northern Kentucky University
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
import time
import os

# %%
# Set up Chrome options
options = Options()
options.headless = True  # Run in headless mode
chrome_driver_path = r"C:\Users\gauur\projects\WEB SCRAPE\Indeed-Job-Scraping\chromedriver.exe"
service = Service(chrome_driver_path)
service

# %%
df_urls  = df[["Link"]]
df_urls
# Out:
#                                                   Link
# 0    https://www.ratemyprofessors.com/professor/439956
# 1    https://www.ratemyprofessors.com/professor/188...
# 2    https://www.ratemyprofessors.com/professor/126452
# 3    https://www.ratemyprofessors.com/professor/165...
# 4    https://www.ratemyprofessors.com/professor/190...
# ..                                                 ...
# 418  https://www.ratemyprofessors.com/professor/225...
# 419  https://www.ratemyprofessors.com/professor/290...
# 420  https://www.ratemyprofessors.com/professor/287...
# 421  https://www.ratemyprofessors.com/professor/294...
# 422  https://www.ratemyprofessors.com/professor/211...
#
# [423 rows x 1 columns]

# %%
driver = webdriver.Chrome()
driver
# Out:
# Metadata cannot be written in cache (C:\Users\gauur\.cache\selenium): Access is denied. (os error 5)
# <selenium.webdriver.chrome.webdriver.WebDriver (session="7c0ae23be620341f0eb5f1effeb61c4e")>

# %%
for index, row in df_urls.iterrows():
    url = row['Link']
    try:
        driver.get(url)
        time.sleep(5)  # Wait for the page to load

        # Get the page source after the comments have loaded
        page_source = driver.page_source

        # Save the HTML page source to a .txt file
        with open(f'page_{index}.txt', 'w', encoding='utf-8') as file:
            file.write(page_source)
        print(f"Saved page source to page_{index}.txt")
    except Exception as e:
        print(f"An error occurred with URL {url}: {e}")
# Out:
# Saved page source to page_0.txt
# Saved page source to page_1.txt
# Saved page source to page_2.txt
# Saved page source to page_3.txt
# Saved page source to page_4.txt
# Saved page source to page_5.txt
# Saved page source to page_6.txt
# Saved page source to page_7.txt
# Saved page source to page_8.txt
# Saved page source to page_9.txt
# Saved page source to page_10.txt
# Saved page source to page_11.txt
# Saved page source to page_12.txt
# Saved page source to page_13.txt
# Saved page source to page_14.txt
# Saved page source to page_15.txt
# Saved page source to page_16.txt
# Saved page source to page_17.txt
# Saved page source to page_18.txt
# Saved page source to page_19.txt
# Saved page source to page_20.txt
# Saved page source to page_21.txt
# Saved page source to page_22.txt
# Saved page source to page_23.txt
# Saved page source to page_24.txt
# Saved page source to page_25.txt
# Saved page source to page_26.txt
# Saved page source to page_27.txt
# ...

# %%
'''all_names = []
all_comments = []
for index, row in df_urls.iterrows():
    url = row['Link']
    try:
        driver.get(url)
        time.sleep(5)  # Wait for the page to load

        # Get the page source after the comments have loaded
        page_source = driver.page_source

        # Parse the page source with BeautifulSoup
        soup = BeautifulSoup(page_source, 'html.parser')

        # Find all names and comments based on their class names
        names_elements = soup.find_all(class_='NameTitle__Name-dowf0z-0 cfjPUG')  # Replace with the actual class for names
        comments_elements = soup.find_all(class_='Comments__StyledComments-dzzyvm-0')

        # Extract text from each name and comment
        names = [name.get_text() for name in names_elements]
        comments = [comment.get_text() for comment in comments_elements]
        print(names)
        print(comments)
        # Ensure lists are the same length, truncate or handle mismatch as needed
        min_length = min(len(names), len(comments))
        names = names[:min_length]
        comments = comments[:min_length]

        # Append to the main lists
        all_names.extend(names)
        all_comments.extend(comments)

    except Exception as e:
        print(f"An error occurred with URL {url}: {e}")

# Close the browser
driver.quit()
'''
# Out:
# 'all_names = []\nall_comments = []\nfor index, row in df_urls.iterrows():\n    url = row[\'Link\']\n    try:\n        driver.get(url)\n        time.sleep(5)  # Wait for the page to load\n\n        # Get the page source after the comments have loaded\n        page_source = driver.page_source\n\n        # Parse the page source with BeautifulSoup\n        soup = BeautifulSoup(page_source, \'html.parser\')\n\n        # Find all names and comments based on their class names\n        names_elements = soup.find_all(class_=\'NameTitle__Name-dowf0z-0 cfjPUG\')  # Replace with the actual class for names\n        comments_elements = soup.find_all(class_=\'Comments__StyledComments-dzzyvm-0\')\n\n        # Extract text from each name and comment\n        names = [name.get_text() for name in names_elements]\n        comments = [comment.get_text() for comment in comments_elements]\n        print(names)\n        print(comments)\n        # Ensure lists are the same length, truncate or handle mismatch
# ...

# %%
# Create a DataFrame with names and comments
df = pd.DataFrame({
    'Name': all_names,
    'Comment': all_comments
})

# Print the DataFrame
print(df)
